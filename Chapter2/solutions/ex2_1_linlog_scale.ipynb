# %%
# Core data handling
import yfinance as yf
import pandas as pd
import numpy as np

# Statistical analysis
from scipy.stats import norm, skew, kurtosis
import arch

# Visualization
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
sns.set_theme(style="darkgrid")
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
tickers = ['BEEF3.SA']

df = pd.DataFrame(yf.download(tickers, start = '2000-1-1', end = '2025-01-01')['Close'])
df
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Ticker       BEEF3.SA
# Date
# 2007-07-20  13.840788
# 2007-07-23  13.695095
# 2007-07-24  13.440131
# 2007-07-25  13.622246
# 2007-07-26  13.330863
# ...               ...
# 2024-12-20   5.540000
# 2024-12-23   5.440000
# 2024-12-26   5.220000
# 2024-12-27   5.180000
# 2024-12-30   5.090000
#
# [4330 rows x 1 columns]

# %%
coluna = 'BEEF3.SA'

fig, axs = plt.subplots(2, 1, figsize=(12, 8))

# 1. Plot linear
axs[0].plot(df.index, df[coluna], label='Preço (Linear)', color='blue')
axs[0].set_title('Preço da Ação BEEF3.SA - Escala Linear')
axs[0].set_ylabel('Preço')
axs[0].grid(True)
axs[0].legend()

# 2. Plot logarítmico
axs[1].plot(df.index, np.log(df[coluna]), label='Log(Preço)', color='green')
axs[1].set_title('Preço da Ação BEEF3.SA - Escala Logarítmica')
axs[1].set_ylabel('Log(Preço)')
axs[1].grid(True)
axs[1].legend()

plt.xlabel('Data')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparing both scales
#
# When comparing linear and logarithmic scales on a financial chart, the key difference lies in how price movements are visually represented. A linear scale displays equal vertical spacing for equal absolute price changes, meaning a move from $10 to $20 looks the same as one from $100 to $110, even though their percentage gains differ greatly. In contrast, a logarithmic scale spaces the chart based on percentage changes, so a 100% increase—from $10 to $20 or $100 to $200—appears equally large. This makes log scales more appropriate for analyzing long-term investments or assets with exponential growth, as they offer a clearer view of relative performance across different price levels. While both charts may look similar over short periods or small price ranges, their interpretations diverge significantly when assessing trends over time or across wide price fluctuations.
